# %% [markdown]
# Generated a 'hard-coded' 5x5 array of uniform random numbers based on a earlier call to np.random.rand(5,5)

# %%
a = np.array([[0.49219331,1.91854060,3.73008558,3.73871810],
              [2.61343131,4.86010406,2.51127627,1.89509224],
              [2.29677542,7.87037584,1.75908862,3.90172707],
              [3.29908321,3.90427730,6.50452315,4.34195073],
              [6.67073259,4.30684616,7.39463457,1.83080513]])

# %%
print a
# Out:
# [[ 0.49219331  1.9185406   3.73008558  3.7387181 ]
#  [ 2.61343131  4.86010406  2.51127627  1.89509224]
#  [ 2.29677542  7.87037584  1.75908862  3.90172707]
#  [ 3.29908321  3.9042773   6.50452315  4.34195073]
#  [ 6.67073259  4.30684616  7.39463457  1.83080513]]

# %%
my_cmap = cmap.bwr
fig = plt.figure(figsize=(10,10))
ax0 = fig.add_subplot(321)
ax0.pcolormesh(a,cmap=my_cmap)
ax1 = fig.add_subplot(322)
ax1.pcolormesh(a,vmin=0,vmax=8,cmap=my_cmap)
ax2 = fig.add_subplot(323)
ax2.pcolormesh(a,vmin=1,vmax=7,cmap=my_cmap)
ax3 = fig.add_subplot(324)
ax3.pcolormesh(a,vmin=2,vmax=6,cmap=my_cmap)
ax4 = fig.add_subplot(325)
ax4.pcolormesh(a,vmin=3,vmax=5,cmap=my_cmap)
ax5 = fig.add_subplot(326)
ax5.pcolormesh(a,vmin=3,vmax=4.5,cmap=my_cmap)

# %%
pwd
# Out:
# u'C:\\Users\\Conrad\\Documents\\GitHub\\matplotlib'
